# %%
print(2+9)
# Out:
# 11

# %%
print (666-66)
# Out:
# 600

# %%
print(52*555)
# Out:
# 28860

# %%
print(67*882)
# Out:
# 59094

# %%
print(890/90)
# Out:
# 9.88888888888889

# %%
print (10/5)
# Out:
# 2.0

# %%
print(10//5)
# Out:
# 2

# %%
print(990//7)
# Out:
# 141

# %%
print(990/7)
# Out:
# 141.42857142857142

# %%
print(3//2)
# Out:
# 1

# %%
print(5%4)
# Out:
# 1

# %%
print(9%7)
# Out:
# 2

# %%
subject =  "ai&ml"
print(subject)
# Out:
# ai&ml

# %%
subject="life is beautiful"
print(subject)
# Out:
# life is beautiful

# %%
#subject ='life is beautiful'
print(subject)
# Out:
# life is beautiful

# %%
subject="how to drive car"
print(subject)
# Out:
# how to drive car

# %%
concept=("how to drive car")
print(concept)
# Out:
# how to drive car

# %%
x=1
y=5
z=x+y
print(z)
# Out:
# 6

# %%
x=8009
y=678
z=y-x
print(z)
# Out:
# -7331

# %%
x=78998
y=789
z=x*y
print(z)
# Out:
# 62329422

# %%
x=89990
y=90
z=(x+y)x
print(z)
# Out:
# 8106299200

# %%
x=7897
y=90
z=x/y*8
print(z)
# Out:
# 701.9555555555555

# %%
subject 1 (gkvk)
subject 2 (agriculture)
print(subject 1+ subject 2)
# Out:
# gkvkagriculture

# %%
subject1 = "gkvk"
subject2 = "agriculture"
print(subject1  + subject2)
# Out:
# gkvkagriculture

# %%
subject1 = "gkvk    "
subject2 = "       agriculture"
print(subject1 + subject2)
# Out:
# gkvk           agriculture

# %%
subject1 = "gkvk"
subject2 = "agriculture"
print(subject1 +"  " + subject2)
# Out:
# gkvk  agriculture

# %%
subject1 = "gkvk"
subject2 = "agriculture"
print(subject1 +" class for   "+ subject2)
# Out:
# gkvk class for   agriculture

# %%
subject1 = "gkvk  "

print(subject1 * 9)
# Out:
# gkvk  gkvk  gkvk  gkvk  gkvk  gkvk  gkvk  gkvk  gkvk

# %%
#a=10
#b=10
#c=10
a=b=c=10
print(a)
print(b)
print(c)
# Out:
# 10
# 10
# 10

# %%
a
b
c
a=b=c=456
print(a)
print(b)
print(c)
# Out:
# 456
# 456
# 456

# %%
a
c
a=T=c=456
print(a)
print(T)
print(c)
# Out:
# 456
# 456
# 456

# %%
_u2=10
print(_u2)
# Out:
# 10
