# %%
s={1,2,3,4,5,6,7}
print(s)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
def max(num1,num2):
  if num1>num2:
    result=num1
  else:
    result=num2
  return result

z=max(9,23)
print(z)
# Out:
# 23

# %%
def min(num1,num2):
  if num1<num2:
    result=num1
  else:
    result=num2
  return result

  z=min(9,3)
  print(z)
