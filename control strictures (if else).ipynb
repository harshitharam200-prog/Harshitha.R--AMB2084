# %%
mar=79
if mar>90:
   print("grade A")
elif mar>70 and mar<90:
   print("grade B")
elif mar>30 and mar<70:
   print("grade C")
else:
   print("fail")
# Out:
# grade B

# %%
hum=50
if hum>50:
   print("rain will come")
else:
   print("rain will not come")
# Out:
# rain will not come

# %%
a=3
b=9
c=a+b
print (c)
# Out:
# 12

# %%
A=( 1, 10, 5):
for i in A:
   print(i)
# Out:
#   File "/tmp/ipython-input-174168046.py", line 1
#     A=( 1 101 5):
#         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
