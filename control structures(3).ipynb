# %%
a= int (input("enter a number"))
b= int(input("enter a number"))
c=a*b
print("the produt of {} and {} is {}". format (a, b ,c))
# Out:
# enter a number7
# enter a number8
# the produt of 7 and 8 is 56

# %%
a=input("enter a number")
b=int(input ("enter a number"))
print(a)
print(b+10)
print(type(a))
print(type(b))
# Out:
# enter a numbershree
# enter a number10
# shree
# 20
# <class 'str'>
# <class 'int'>

# %%
a=20
b=40
if a>b:
  print("a is greater than b")
else:
  print(" b is greater than a")
# Out:
#  b is greater than a

# %%
a=60
if a>90:
  print(" grade A")
elif a>70 and a<90:
  print("grade B")
elif a>50 and a<70:
  print("grade C")
else:
  print ("fail")
# Out:
# grade C

# %%
pi=3.14
r=2
a=pi*r*r
p=2*3.14*r
ch=int(input("enter 1 for area, 2 for perimeter calculation"))
if (ch==1):
  print("area of ciecle is",a)
elif (ch==2):
  print ("perimeter of circle is", b)
else:
  print("print a valid number")
# Out:
# enter 1 for area, 2 for perimeter calculation3
# print a valid number

# %%
a=70
if a%5==0 and a%7==0 :
  print("a is divisible by 5 and 7")
else:
  print(" a is not divisible by 5 and 7")
# Out:
# a is divisible by 5 and 7

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
if(a>b):
  print("{}is greater between {}and{}".format(a,a,b))
elif(b>a):
  print("{} is greater between {} and{}".format(b,a,b))
else:
  print("{}and{} are equal".format(a,b))
# Out:
# enter a number5
# enter a number4
# 5is greater between 5and4

# %%
list1= [1,2,3.0,'hi',4]
      # 0 1 2     3  4
print(list1)
# Out:
# [1, 2, 3.0, 'hi', 4]

# %%
print(len(list1))
# Out:
# 5

# %%
print(list1.index('hi'))
# Out:
# 3

# %%
print(list1.index('hi'))
list1.append('hi')
print(list1)
# Out:
# 3
# [1, 2, 3.0, 'hi', 4, 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi']

# %%
print(list1.insert(0,"hi"))
print(list1)
# Out:
# None
# ['hi', 'hi', 1, 2, 3.0, 'hi', 4, 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi']

# %%
list1.remove('hi')
print(list1)
# Out:
# [1, 2, 3.0, 'hi', 4, 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi', 'hi']

# %%
list1=[20,40,2]
print(list1)
# Out:
# [20, 40, 2]

# %%
list1.sort()
print(list1)
# Out:
# [2, 20, 40]

# %%
list1=
