# %%
x="hiii"
print (x)
# Out:
# hiii

# %%
list1=[10,20,30,40,50]
list1[2:7]
# Out:
# [30, 40, 50]

# %%
list1=[10,20,30,40,50]
list1[2:]
# Out:
# [30, 40, 50]

# %%
list1=[10,20,30,40,50]
list1[-3:-1]
# Out:
# [30, 40]

# %%
list1=[10,20,30,40,50,60]
list1[1:6:]
# Out:
# [20, 30, 40, 50, 60]

# %%
list1=["ice","coffee","latte","espresso","mocha","macchiato"]
list1[-6:-1:3]
# Out:
# ['ice', 'espresso']

# %%
coffee=["latte","mocha","boba","macchiato","espresso","americano"]
print(coffee[1:-1])
# Out:
# ['mocha', 'boba', 'macchiato', 'espresso']

# %%
numbers=[10,20,30,40,50]
for i in numbers:
  print(i+3)
# Out:
# 13
# 23
# 33
# 43
# 53

# %%
numbers=[10,20,30,40,50,60]
n=[]
for i in numbers:
  n.append(i+2)
print("new list", n)
print("original list",numbers)
# Out:
# new list [12, 22, 32, 42, 52, 62]
# original list [10, 20, 30, 40, 50, 60]

# %%
numbers=[10,20,30,40,50]
n=[i+5 for i in numbers]
print("new list",n)
print("original list",numbers)
# Out:
# new list [15, 25, 35, 45, 55]
# original list [10, 20, 30, 40, 50]

# %%
coffee=[2,3]
n=[i+ 2 for i in coffee]
print("new list",n)
print("original list",coffee)
# Out:
# new list [4, 5]
# original list [2, 3]

# %%
numbers=[4,16,29,20]
n=[ i for i in numbers if i%4==0 ]
print("numbrs divisible by 4",n)
print("original list",numbers)
# Out:
# numbrs divisible by 4 [4, 16, 20]
# original list [4, 16, 29, 20]

# %%
numbers=[4,16,29,20]
n=[]
for i in numbers:
 if i%4==0:
  n.append(i)
print("numbers divisible by 4",n)
print("original list",numbers)
# Out:
# numbers divisible by 4 [4, 16, 20]
# original list [4, 16, 29, 20]

# %%
numbers=[12,34,56,87,89]
n=["even" if i%2==0 else "odd" for i in numbers]
print(n)
# Out:
# ['even', 'even', 'even', 'odd', 'odd']

# %%
numbers=[12,34,56,87,89]
n=[i for i in numbers if i%2==0]
print("the number is even",n)
print("original list",numbers)
# Out:
# the number is even [12, 34, 56]
# original list [12, 34, 56, 87, 89]

# %%
cost=[85000,25000,45600,6578]
cost=[i*0.08+i for i in cost]
print(cost)
# Out:
# [91800.0, 27000.0, 49248.0, 7104.24]
